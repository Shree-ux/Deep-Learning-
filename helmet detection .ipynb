# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# Function to load and preprocess images
def load_and_preprocess_data(data_dir, img_size=(150, 150)):
    images = []
    labels = []

    for folder_name in os.listdir(data_dir):
        folder_path = os.path.join(data_dir, folder_name)
        # Skip if it's not a directory
        if not os.path.isdir(folder_path):
            continue
        if folder_name == 'helmet':  # Assuming 'helmet' folder contains images of people wearing helmets
            label = 1
        else:
            label = 0  # Assuming other folders contain images of people not wearing helmets

        for filename in os.listdir(folder_path):
            # Skip hidden files
            if filename.startswith('.'):
                continue
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            img = cv2.resize(img, img_size)
            img = img / 255.0  # Normalize pixel values
            images.append(img)
            labels.append(label)

    return np.array(images), np.array(labels)

# Load and preprocess data
data_dir = '/Users/csshreejit/Desktop/data/'
images, labels = load_and_preprocess_data(data_dir)

# Split data into training and validation sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Print shapes to verify
print("Training data shape:", X_train.shape)
print("Testing data shape:", X_test.shape)
print("Training labels shape:", y_train.shape)
print("Testing labels shape:", y_test.shape)
# Out:
# Training data shape: (22, 150, 150, 3)
# Testing data shape: (6, 150, 150, 3)
# Training labels shape: (22,)
# Testing labels shape: (6,)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Define the CNN model
def create_model(input_shape):
    model = models.Sequential()

    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))  # Adding dropout for regularization
    model.add(layers.Dense(1, activation='sigmoid'))  # Output layer with sigmoid activation for binary classification

    return model

# Set input image dimensions
img_width, img_height = 150, 150
input_shape = (img_width, img_height, 3)  # Assuming RGB images

# Create the model
model = create_model(input_shape)

# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model.summary()

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=10, validation_split=0.2)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 3s 69ms/step - loss: 3.3625e-35 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 6/50
# 50/50 [==============================] - 4s 73ms/step - loss: 1.5142e-28 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 7/50
# 50/50 [==============================] - 3s 70ms/step - loss: 1.8324e-33 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 8/50
# 50/50 [==============================] - 3s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 9/50
# 50/50 [==============================] - 3s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 10/50
# 50/50 [==============================] - 4s 73ms/step - loss: 1.7467e-33 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 11/50
# 50/50 [==============================] - 4s 71ms/step - loss: 5.8939e-38 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 12/50
# 50/50 [==============================] - 3s 70ms/step - loss: 8.8345e-38 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 13/50
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 14/50
# 50/50 [==============================] - 4s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 15/50
# 50/50 [==============================] - 4s 75ms/step - loss: 6.0462e-37 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 16/50
# 50/50 [==============================] - 4s 81ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 17/50
# 50/50 [==============================] - 4s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 18/50
# 50/50 [==============================] - 4s 78ms/step - loss: 2.1514e-37 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 19/50
# 50/50 [==============================] - 4s 76ms/step - loss: 2.8885e-37 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 20/50
# 50/50 [==============================] - 4s 74ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 21/50
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 22/50
# 50/50 [==============================] - 4s 73ms/step - loss: 8.8562e-35 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 23/50
# 50/50 [==============================] - 4s 74ms/step - loss: 1.9979e-36 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 24/50
# 50/50 [==============================] - 4s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 25/50
# 50/50 [==============================] - 4s 71ms/step - loss: 7.3254e-34 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 26/50
# 50/50 [==============================] - 4s 73ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 27/50
# 50/50 [==============================] - 4s 73ms/step - loss: 3.7491e-35 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 28/50
# 50/50 [==============================] - 4s 70ms/step - loss: 4.3191e-33 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 29/50
# 50/50 [==============================] - 3s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 30/50
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 31/50
# 50/50 [==============================] - 4s 74ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 32/50
# 50/50 [==============================] - 4s 79ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 33/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 34/50
# 50/50 [==============================] - 4s 74ms/step - loss: 7.6308e-35 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 35/50
# 50/50 [==============================] - 4s 76ms/step - loss: 1.9652e-37 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 36/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.1756e-36 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 37/50
# 50/50 [==============================] - 4s 70ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 38/50
# 50/50 [==============================] - 4s 74ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 39/50
# 50/50 [==============================] - 3s 69ms/step - loss: 5.8482e-34 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 40/50
# 50/50 [==============================] - 3s 69ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 41/50
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 42/50
# 50/50 [==============================] - 4s 76ms/step - loss: 1.6725e-30 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 43/50
# 50/50 [==============================] - 4s 77ms/step - loss: 4.0499e-38 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 44/50
# 50/50 [==============================] - 4s 73ms/step - loss: 2.0993e-28 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 45/50
# 50/50 [==============================] - 4s 73ms/step - loss: 3.6683e-37 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 46/50
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 47/50
# 50/50 [==============================] - 4s 73ms/step - loss: 4.4448e-37 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 48/50
# 50/50 [==============================] - 4s 73ms/step - loss: 8.5134e-37 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 49/50
# 50/50 [==============================] - 4s 74ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 50/50
# 50/50 [==============================] - 4s 74ms/step - loss: 1.4351e-33 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000

# %%
# Evaluate the model on validation data
test_loss, test_acc = model.evaluate(X_test, y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Test Loss: 0.0
# Test Accuracy: 1.0

# %%
import matplotlib.pyplot as plt

# Create subplots for accuracy and loss
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Plot training & validation accuracy values
axes[0].plot(history.history['accuracy'])
axes[0].plot(history.history['val_accuracy'])
axes[0].set_title('Model accuracy')
axes[0].set_ylabel('Accuracy')
axes[0].set_xlabel('Epoch')
axes[0].legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
axes[1].plot(history.history['loss'])
axes[1].plot(history.history['val_loss'])
axes[1].set_title('Model loss')
axes[1].set_ylabel('Loss')
axes[1].set_xlabel('Epoch')
axes[1].legend(['Train', 'Validation'], loc='upper left')

# Adjust layout
plt.tight_layout()

# Show plots
plt.show()

# %%
# Function to preprocess an image
def preprocess_image(image_path):
    img = cv2.imread(image_path)
    img = cv2.resize(img, (150, 150))  # Resize the image to match the input shape of your model
    img = img / 255.0  # Normalize pixel values
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# Path to the image you want to make prediction on
image_path = '/Users/harsha/Desktop/data/img1.jpg'  # Replace this with the full path to your image file

# Preprocess the image
processed_image = preprocess_image(image_path)

# Make predictions
predictions = model.predict(processed_image)

# Interpret predictions
if predictions[0][0] > 0.5:  # Assuming 0.5 as the threshold
    print("Person is wearing a helmet.")
else:
    print("Person is not wearing a helmet.")
# Out:
# [ WARN:0@968.839] global loadsave.cpp:248 findDecoder imread_('/Users/harsha/Desktop/data/img1.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 13
#      10 image_path = '/Users/harsha/Desktop/data/img1.jpg'  # Replace this with the full path to your image file
#      12 # Preprocess the image
# ---> 13 processed_image = preprocess_image(image_path)
#      15 # Make predictions
#      16 predictions = model.predict(processed_image)
#
# Cell In[13], line 4, in preprocess_image(image_path)
#       2 def preprocess_image(image_path):
#       3     img = cv2.imread(image_path)
# ----> 4     img = cv2.resize(img, (150, 150))  # Resize the image to match the input shape of your model
#       5     img = img / 255.0  # Normalize pixel values
#       6     img = np.expand_dims(img, axis=0)  # Add batch dimension
#
# error: OpenCV(4.9.0) /Users/xperience/GHA-OpenCV-Python2/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
